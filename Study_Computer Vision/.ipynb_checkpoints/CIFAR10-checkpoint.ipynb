# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

plt.style.use('seaborn')
sns.set(font_scale=2.5)
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
lst = []
for i,im in enumerate(y_train):
  if im==1:
    lst.append(i)
print(lst)
lst = np.array(lst)
# Out:
# [4, 5, 32, 44, 45, 46, 60, 61, 64, 65, 75, 79, 94, 96, 97, 99, 105, 112, 119, 126, 134, 136, 137, 140, 160, 168, 176, 184, 201, 206, 212, 226, 227, 236, 238, 250, 255, 257, 261, 262, 275, 282, 301, 302, 304, 311, 312, 323, 325, 330, 354, 364, 375, 389, 393, 396, 427, 432, 454, 461, 466, 482, 486, 493, 498, 506, 524, 536, 547, 561, 565, 568, 576, 578, 590, 593, 599, 606, 617, 644, 676, 690, 699, 714, 743, 747, 753, 761, 772, 815, 823, 833, 834, 835, 840, 841, 848, 855, 873, 874, 879, 893, 917, 936, 942, 947, 962, 977, 978, 980, 991, 997, 1006, 1020, 1021, 1029, 1037, 1052, 1064, 1068, 1079, 1090, 1095, 1103, 1145, 1153, 1170, 1240, 1242, 1251, 1287, 1293, 1301, 1304, 1305, 1320, 1356, 1364, 1377, 1380, 1389, 1394, 1408, 1410, 1413, 1421, 1446, 1448, 1455, 1464, 1476, 1494, 1502, 1520, 1541, 1547, 1548, 1551, 1559, 1565, 1570, 1571, 1574, 1578, 1586, 1599, 1604, 1605, 1611, 1621, 1631, 1651, 1660, 1681, 1689, 1694, 1707, 1724, 1731, 1736, 1747, 1781, 1790, 1799, 1820, 1869, 1901, 1907, 1946, 1973, 1985, 2005, 2023, 2029, 2037, 2038, 2039, 2046, 2052, 2067, 2072, 2084, 2094, 2101, 2118, 2143, 2149, 2153, 2173, 2180, 2184, 2185, 2186, 2200, 2204, 2227, 2249, 2250, 2259, 2268, 2280, 2283, 2286, 2289, 2306, 2318, 2320, 2328, 2339, 2362, 2389, 2390, 2394, 2422, 2428, 2431, 2433, 2445, 2455, 2456, 2466, 2469, 2496, 2511, 2545, 2568, 2569, 2570, 2582, 2584, 2587, 2588, 2597, 2600, 2615, 2628, 2630, 2656, 2661, 2727, 2731, 2752, 2753, 2756, 2762, 2765, 2769, 2771, 2775, 2795, 2800, 2802, 2825, 2827, 2828, 2837, 2841, 2844, 2849, 2851, 2862, 2883, 2887, 2910, 2928, 2958, 2994, 3009, 3020, 3025, 3034, 3059, 3062, 3064, 3072, 3078, 3085, 3103, 3120, 3131, 3142, 3183, 3212, 3230, 3231, 3233, 3238, 3257, 3273, 3285, 3315, 3327, 3346, 3366, 3378, 3379, 3386, 3387, 3399, 3404, 3414, 3415, 3444, 3452, 3467, 3483, 3485, 3505, 3512, 3523, 3555, 3601, 3605, 3620, 3659, 3661, 3678, 3727, 3734, 3735, 3743, 3744, 3773, 3779, 3781, 3808, 3822, 3827, 3830, 3836, 3840, 3851, 3871, 3886, 3899, 3907, 3911, 3922, 3924, 3934, 3935, 3937, 3954, 3984, 3990, 3992, 4006, 4011, 4013, 4021, 4039, 4040, 4047, 4050, 4084, 4099, 4100, 4101, 4132, 4145, 4171, 4172, 4185, 4200, 4206, 4230, 4244, 4250, 4261, 4265, 4299, 4326, 4327, 4332, 4334, 4352, 4354, 4358, 4360, 4363, 4379, 4385, 4390, 4423, 4443, 4444, 4458, 4459, 4464, 4492, 4496, 4500, 4505, 4517, 4528, 4533, 4553, 4557, 4560, 4562, 4565, 4578, 4585, 4591, 4607, 4609, 4615, 4624, 4625, 4631, 4636, 4648, 4654, 4661, 4664, 4696, 4739, 4762, 4764, 4769, 4775, 4797, 4803, 4840, 4856, 4858, 4866, 4909, 4917, 4927, 4932, 4942, 4944, 4945, 4949, 4953, 4958, 4977, 4983, 4993, 5014, 5021, 5052, 5070, 5076, 5084, 5099, 5102, 5112, 5125, 5137, 5144, 5146, 5149, 5157, 5171, 5181, 5195, 5196, 5197, 5202, 5207, 5211, 5224, 5232, 5236, 5243, 5247, 5257, 5261, 5282, 5287, 5301, 5311, 5334, 5337, 5344, 5356, 5387, 5392, 5420, 5422, 5433, 5438, 5459, 5460, 5512, 5515, 5552, 5559, 5567, 5568, 5572, 5590, 5616, 5627, 5629, 5632, 5635, 5663, 5666, 5683, 5685, 5709, 5714, 5722, 5747, 5759, 5769, 5791, 5805, 5810, 5811, 5816, 5822, 5827, 5831, 5834, 5841, 5860, 5885, 5895, 5897, 5917, 5939, 5947, 5951, 5959, 5971, 5975, 5983, 6020, 6031, 6040, 6064, 6068, 6074, 6078, 6109, 6120, 6121, 6122, 6130, 6136, 6137, 6141, 6161, 6191, 6196, 6226, 6231, 6233, 6241, 6244, 6269, 6272, 6285, 6295, 6302, 6318, 6325, 6347, 6349, 6353, 6356, 6366, 6371, 6375, 6383, 6411, 6420, 6429, 6434, 6446, 6453, 6456, 6464, 6489, 6494, 6495, 6515, 6534, 6544, 6550, 6559, 6589, 6608, 6623, 6630, 6639, 6656, 6659, 6661, 6668, 6670, 6673, 6678, 6683, 6701, 6703, 6709, 6725, 6731, 6733, 6736, 6737, 6751, 6765, 6769, 6779, 6786, 6798, 6813, 6814, 6819, 6820, 6828, 6831, 6851, 6869, 6871, 6885, 6889, 6895, 6896, 6899, 6908, 6915, 6922, 6928, 6931, 6933, 6955, 6959, 6967, 6969, 6971, 6988, 7005, 7018, 7019, 7048, 7077, 7087, 7102, 7124, 7130, 7145, 7147, 7148, 7173, 7176, 7177, 7198, 7214, 7221, 7238, 7255, 7261, 7271, 7284, 7286, 7288, 7289, 7297, 7300, 7312, 7324, 7 ...

# %%
for i in range(3):
  plt.imshow(x_train[lst[i]])
  plt.show()

# %%
#Part A

# %%
train_datagen = ImageDataGenerator(
  rescale = 1./255.,
  width_shift_range= 0.2,
  zoom_range = 0.3,
  horizontal_flip = True
)
test_datagen = ImageDataGenerator(
  rescale = 1./255.
)

# %%
train_generator = train_datagen.flow(
    x_train,y_train
)
validation_generator = test_datagen.flow(
    x_test,y_test
)

# %%
#modeling

inputs = layers.Input(shape=(32,32,3))

net = layers.Conv2D(32,5,1,padding='SAME')(inputs)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Conv2D(64,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Conv2D(128,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Flatten()(net)
net = layers.Dense(500)(net)
net = layers.Dropout(0.5)(net)
net = layers.BatchNormalization()(net)
net = layers.Activation('relu')(net)
net = layers.Dense(10)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs = inputs, outputs = net, name = 'CNN')

# %%
model.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 500)               2000
# _________________________________________________________________
# activation_8 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,257,366
# Trainable params: 1,256,366
# Non-trainable params: 1,000
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
                loss = 'sparse_categorical_crossentropy',
                metrics = [tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = len(train_generator),
    epochs=20,
    validation_data=validation_generator,
    validation_steps = len(validation_generator)
)
# Out:
# Epoch 1/20
#    4/1563 [..............................] - ETA: 33s - loss: 0.9070 - sparse_categorical_accuracy: 0.6484
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.8475 - sparse_categorical_accuracy: 0.7043 - val_loss: 0.7715 - val_sparse_categorical_accuracy: 0.7332
# Epoch 2/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.8306 - sparse_categorical_accuracy: 0.7124 - val_loss: 0.8115 - val_sparse_categorical_accuracy: 0.7282
# Epoch 3/20
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7997 - sparse_categorical_accuracy: 0.7215 - val_loss: 0.8036 - val_sparse_categorical_accuracy: 0.7281
# Epoch 4/20
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.7883 - sparse_categorical_accuracy: 0.7264 - val_loss: 0.8354 - val_sparse_categorical_accuracy: 0.7088
# Epoch 5/20
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7691 - sparse_categorical_accuracy: 0.7310 - val_loss: 0.7338 - val_sparse_categorical_accuracy: 0.7452
# Epoch 6/20
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.7532 - sparse_categorical_accuracy: 0.7369 - val_loss: 0.7648 - val_sparse_categorical_accuracy: 0.7396
# Epoch 7/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.7393 - sparse_categorical_accuracy: 0.7432 - val_loss: 0.6711 - val_sparse_categorical_accuracy: 0.7766
# Epoch 8/20
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7260 - sparse_categorical_accuracy: 0.7485 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.7589
# Epoch 9/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.7044 - sparse_categorical_accuracy: 0.7558 - val_loss: 0.6845 - val_sparse_categorical_accuracy: 0.7673
# Epoch 10/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6971 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.7589 - val_sparse_categorical_accuracy: 0.7543
# Epoch 11/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6913 - sparse_categorical_accuracy: 0.7607 - val_loss: 0.6369 - val_sparse_categorical_accuracy: 0.7835
# Epoch 12/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6762 - sparse_categorical_accuracy: 0.7644 - val_loss: 0.6689 - val_sparse_categorical_accuracy: 0.7748
# Epoch 13/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6659 - sparse_categorical_accuracy: 0.7711 - val_loss: 0.6352 - val_sparse_categorical_accuracy: 0.7884
# Epoch 14/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6547 - sparse_categorical_accuracy: 0.7721 - val_loss: 0.7064 - val_sparse_categorical_accuracy: 0.7590
# Epoch 15/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6416 - sparse_categorical_accuracy: 0.7783 - val_loss: 0.6223 - val_sparse_categorical_accuracy: 0.7922
# Epoch 16/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6355 - sparse_categorical_accuracy: 0.7798 - val_loss: 0.7499 - val_sparse_categorical_accuracy: 0.7495
# Epoch 17/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6281 - sparse_categorical_accuracy: 0.7823 - val_loss: 0.6737 - val_sparse_categorical_accuracy: 0.7705
# Epoch 18/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6207 - sparse_categorical_accuracy: 0.7848 - val_loss: 0.6549 - val_sparse_categorical_accuracy: 0.7781
# Epoch 19/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6140 - sparse_categorical_accuracy: 0.7880 - val_loss: 0.6377 - val_sparse_categorical_accuracy: 0.7840
# Epoch 20/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6014 - sparse_categorical_accuracy: 0.7890 - val_loss: 0.6273 - val_sparse_categorical_accuracy: 0.7900

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 271.8545 - sparse_categorical_accuracy: 0.4876
# [271.8544616699219, 0.4875999987125397]

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#Part B

# %%
train_datagen = ImageDataGenerator(
  rescale = 1./255.,
  width_shift_range= 0.2,
  zoom_range = 0.3,
  horizontal_flip = True
)
test_datagen = ImageDataGenerator(
  rescale = 1./255.
)

# %%
train_generator = train_datagen.flow(
    x_train,y_train
)
validation_generator = test_datagen.flow(
    x_test,y_test
)

# %%
#modeling

inputs = layers.Input(shape=(32,32,3))

net = layers.Conv2D(32,5,1,padding='SAME')(inputs)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Conv2D(32,1,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(32,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(64,1,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Conv2D(64,1,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(64,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(128,1,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Flatten()(net)
net = layers.Dense(500)(net)
net = layers.Dropout(0.5)(net)
net = layers.BatchNormalization()(net)
net = layers.Activation('relu')(net)
net = layers.Dense(10)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs = inputs, outputs = net, name = 'CNN')

# %%
model.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 32)        1056
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 64)        2112
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          4160
# _________________________________________________________________
# activation_14 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         8320
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# activation_17 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,095,766
# Trainable params: 1,094,766
# Non-trainable params: 1,000
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
                loss = 'sparse_categorical_crossentropy',
                metrics = [tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = len(train_generator),
    epochs=20,
    validation_data=validation_generator,
    validation_steps = len(validation_generator)
)
# Out:
# Epoch 1/20
#    3/1563 [..............................] - ETA: 39s - loss: 1.7964 - sparse_categorical_accuracy: 0.3646
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.5782 - sparse_categorical_accuracy: 0.4281 - val_loss: 1.5212 - val_sparse_categorical_accuracy: 0.4566
# Epoch 2/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4265 - sparse_categorical_accuracy: 0.4862 - val_loss: 1.2441 - val_sparse_categorical_accuracy: 0.5518
# Epoch 3/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.3112 - sparse_categorical_accuracy: 0.5332 - val_loss: 1.1377 - val_sparse_categorical_accuracy: 0.5918
# Epoch 4/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2210 - sparse_categorical_accuracy: 0.5688 - val_loss: 1.0378 - val_sparse_categorical_accuracy: 0.6303
# Epoch 5/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1463 - sparse_categorical_accuracy: 0.5958 - val_loss: 1.0418 - val_sparse_categorical_accuracy: 0.6341
# Epoch 6/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0981 - sparse_categorical_accuracy: 0.6127 - val_loss: 0.9907 - val_sparse_categorical_accuracy: 0.6470
# Epoch 7/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0521 - sparse_categorical_accuracy: 0.6310 - val_loss: 0.9217 - val_sparse_categorical_accuracy: 0.6774
# Epoch 8/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0190 - sparse_categorical_accuracy: 0.6410 - val_loss: 0.9095 - val_sparse_categorical_accuracy: 0.6825
# Epoch 9/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.9904 - sparse_categorical_accuracy: 0.6510 - val_loss: 0.8813 - val_sparse_categorical_accuracy: 0.6985
# Epoch 10/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9626 - sparse_categorical_accuracy: 0.6629 - val_loss: 0.8815 - val_sparse_categorical_accuracy: 0.7020
# Epoch 11/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9416 - sparse_categorical_accuracy: 0.6703 - val_loss: 0.8701 - val_sparse_categorical_accuracy: 0.6940
# Epoch 12/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9206 - sparse_categorical_accuracy: 0.6795 - val_loss: 0.8166 - val_sparse_categorical_accuracy: 0.7245
# Epoch 13/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9016 - sparse_categorical_accuracy: 0.6851 - val_loss: 0.9112 - val_sparse_categorical_accuracy: 0.6797
# Epoch 14/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8853 - sparse_categorical_accuracy: 0.6921 - val_loss: 0.7915 - val_sparse_categorical_accuracy: 0.7241
# Epoch 15/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8742 - sparse_categorical_accuracy: 0.6925 - val_loss: 0.8259 - val_sparse_categorical_accuracy: 0.7168
# Epoch 16/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8604 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.8384 - val_sparse_categorical_accuracy: 0.7093
# Epoch 17/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8491 - sparse_categorical_accuracy: 0.7039 - val_loss: 0.7766 - val_sparse_categorical_accuracy: 0.7341
# Epoch 18/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8356 - sparse_categorical_accuracy: 0.7087 - val_loss: 0.7435 - val_sparse_categorical_accuracy: 0.7515
# Epoch 19/20
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.8177 - sparse_categorical_accuracy: 0.7160 - val_loss: 0.7730 - val_sparse_categorical_accuracy: 0.7343
# Epoch 20/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8176 - sparse_categorical_accuracy: 0.7149 - val_loss: 0.7663 - val_sparse_categorical_accuracy: 0.7359

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 374.6362 - sparse_categorical_accuracy: 0.4170
# [374.63623046875, 0.4169999957084656]

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#Part C

# %%
train_datagen = ImageDataGenerator(
  rescale = 1./255.,
  width_shift_range= 0.2,
  zoom_range = 0.3,
  horizontal_flip = True
)
test_datagen = ImageDataGenerator(
  rescale = 1./255.
)

# %%
train_generator = train_datagen.flow(
    x_train,y_train
)
validation_generator = test_datagen.flow(
    x_test,y_test
)

# %%
#modeling

inputs = layers.Input(shape=(32,32,3))

net = layers.Conv2D(32,5,1,padding='SAME')(inputs)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.DepthwiseConv2D(3,1,padding = 'valid')(net)
net = layers.SeparableConv2D(32,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.DepthwiseConv2D(3,1,padding = 'valid')(net)
net = layers.SeparableConv2D(64,3,1,padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPool2D((2,2))(net)

net = layers.Flatten()(net)
net = layers.Dense(500)(net)
net = layers.Dropout(0.5)(net)
net = layers.BatchNormalization()(net)
net = layers.Activation('relu')(net)
net = layers.Dense(10)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs = inputs, outputs = net, name = 'CNN')

# %%
model.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 14, 14, 32)        320
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 14, 14, 32)        1344
# _________________________________________________________________
# activation_20 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 5, 5, 32)          320
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 5, 5, 64)          2400
# _________________________________________________________________
# activation_21 (Activation)   (None, 5, 5, 64)          0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               128500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 500)               2000
# _________________________________________________________________
# activation_22 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_23 (Activation)   (None, 10)                0
# =================================================================
# Total params: 142,326
# Trainable params: 141,326
# Non-trainable params: 1,000
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
                loss = 'sparse_categorical_crossentropy',
                metrics = [tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = len(train_generator),
    epochs=20,
    validation_data=validation_generator,
    validation_steps = len(validation_generator)
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 1563/1563 [==============================] - 37s 23ms/step - loss: 2.0201 - sparse_categorical_accuracy: 0.2351 - val_loss: 1.5579 - val_sparse_categorical_accuracy: 0.4324
# Epoch 2/20
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.5806 - sparse_categorical_accuracy: 0.4238 - val_loss: 1.3226 - val_sparse_categorical_accuracy: 0.5197
# Epoch 3/20
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.4736 - sparse_categorical_accuracy: 0.4722 - val_loss: 1.3125 - val_sparse_categorical_accuracy: 0.5274
# Epoch 4/20
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.4069 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.2333 - val_sparse_categorical_accuracy: 0.5615
# Epoch 5/20
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3559 - sparse_categorical_accuracy: 0.5170 - val_loss: 1.2552 - val_sparse_categorical_accuracy: 0.5653
# Epoch 6/20
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.3135 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.1931 - val_sparse_categorical_accuracy: 0.5810
# Epoch 7/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2878 - sparse_categorical_accuracy: 0.5439 - val_loss: 1.2231 - val_sparse_categorical_accuracy: 0.5550
# Epoch 8/20
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.2677 - sparse_categorical_accuracy: 0.5479 - val_loss: 1.1123 - val_sparse_categorical_accuracy: 0.6098
# Epoch 9/20
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.2294 - sparse_categorical_accuracy: 0.5682 - val_loss: 1.1600 - val_sparse_categorical_accuracy: 0.5964
# Epoch 10/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2088 - sparse_categorical_accuracy: 0.5742 - val_loss: 1.1152 - val_sparse_categorical_accuracy: 0.6107
# Epoch 11/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2004 - sparse_categorical_accuracy: 0.5765 - val_loss: 1.0983 - val_sparse_categorical_accuracy: 0.6100
# Epoch 12/20
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.1832 - sparse_categorical_accuracy: 0.5817 - val_loss: 1.0748 - val_sparse_categorical_accuracy: 0.6323
# Epoch 13/20
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.1785 - sparse_categorical_accuracy: 0.5833 - val_loss: 1.0875 - val_sparse_categorical_accuracy: 0.6261
# Epoch 14/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1577 - sparse_categorical_accuracy: 0.5909 - val_loss: 1.0617 - val_sparse_categorical_accuracy: 0.6376
# Epoch 15/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1438 - sparse_categorical_accuracy: 0.5982 - val_loss: 1.0721 - val_sparse_categorical_accuracy: 0.6263
# Epoch 16/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1347 - sparse_categorical_accuracy: 0.6010 - val_loss: 1.0470 - val_sparse_categorical_accuracy: 0.6364
# Epoch 17/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1283 - sparse_categorical_accuracy: 0.5999 - val_loss: 1.0335 - val_sparse_categorical_accuracy: 0.6500
# Epoch 18/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1170 - sparse_categorical_accuracy: 0.6073 - val_loss: 1.0601 - val_sparse_categorical_accuracy: 0.6427
# Epoch 19/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1010 - sparse_categorical_accuracy: 0.6087 - val_loss: 1.0390 - val_sparse_categorical_accuracy: 0.6411
# Epoch 20/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1015 - sparse_categorical_accuracy: 0.6132 - val_loss: 1.0727 - val_sparse_categorical_accuracy: 0.6238

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 273.8783 - sparse_categorical_accuracy: 0.4022
# [273.8782653808594, 0.40220001339912415]

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
